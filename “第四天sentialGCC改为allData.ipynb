# %% [markdown]
# <a href="https://colab.research.google.com/github/mianyumifen-bot/codePublic/blob/main/%E2%80%9C%E7%AC%AC%E5%9B%9B%E5%A4%A9sentialGCC%E6%94%B9%E4%B8%BAallData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 安装必要包（只需运行一次）
# !pip install --quiet earthengine-api geemap rasterio rioxarray geopandas shapely pyproj
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# 授权并挂载 Google Drive，然后初始化 Earth Engine
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

import os, time, json, math
import geopandas as gpd
import pandas as pd
import ee
import geemap

# Earth Engine 授权并初始化（会弹出链接）
try:
    ee.Initialize(project="ee-mianyumifen")
    print("Earth Engine 已初始化。")
except Exception as e:
    print("需要 EE 授权，开始交互式授权流程...")
    ee.Authenticate()
    ee.Initialize(project="ee-mianyumifen")
    print("Earth Engine 已授权并初始化。")

# 常用打印确认
print("当前工作目录：", os.getcwd())
print("Drive 挂载路径：/content/drive")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Mounted at /content/drive
# Earth Engine 已初始化。
# 当前工作目录： /content
# Drive 挂载路径：/content/drive

# %%
# ========== 请修改下面两个路径为你 Drive 中实际的位置 ==========
DRIVE_INPUT_DIR = '/content/drive/MyDrive/allRoi'   # 放 allRoi.shp 的目录
OUT_DRIVE_FOLDER = 'sential2GCC_exports_final_allData'                        # 导出到 Drive 的文件夹名（在 MyDrive 下）
LOG_PATH = os.path.join(DRIVE_INPUT_DIR, 'sential2_export_log.json')  # 导出日志路径

# 其他控制参数
HLS_COLLECTION = 'COPERNICUS/S2_SR_HARMONIZED'  # sential2 数据集

PREFERRED_BANDS = ['B4', 'B3', 'B2', 'B11'] # Red, Green, Blue, and B6 (SWIR1)

EXPORT_SCALE = 10 # meters（sential的近红外是20m的）
MAX_BANDS_WARN = 12000  # 如果堆栈波段超过此数，脚本会改为按月合成导出以避免过大单文件
SLEEP_BETWEEN_START = 1  # 启动导出任务时的间隔秒数（防并发过高）
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# 读取 ROI shapefile（确保 .shp/.dbf/.shx/.prj 都在同一目录）
roi_shp_path = os.path.join(DRIVE_INPUT_DIR, 'allRoi.shp')
if not os.path.exists(roi_shp_path):
    raise FileNotFoundError(f"找不到 {roi_shp_path}，请把 allRoi.shp 放到 DRIVE_INPUT_DIR 指定的目录下。")

rois_gdf = gpd.read_file(roi_shp_path)
print("读取 ROI 数量：", len(rois_gdf))
print("字段名示例：", rois_gdf.columns.tolist())

# 选择名称字段（优先 'site' 或 'name'，否则创建基于索引的 site 字段）
if 'site' in rois_gdf.columns:
    name_field = 'site'
elif 'name' in rois_gdf.columns:
    name_field = 'name'
else:
    name_field = 'site'
    rois_gdf[name_field] = [f"roi_{i}" for i in range(len(rois_gdf))]
    print("未找到 name/site 字段，已自动生成 'site' 字段。")

# 构建字典：site_name -> shapely geometry
roi_dict = {str(row[name_field]): row.geometry for _, row in rois_gdf.iterrows()}
print("示例 site keys:", list(roi_dict.keys())[:10])
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 读取 ROI 数量： 11
# 字段名示例： ['name', 'Shape_Leng', 'Shape_Le_1', 'Shape_Area', 'geometry']
# 示例 site keys: ['northinletsaltmarsh', 'norriepoint', 'mayberry', 'hillslough', 'gcesapelo', 'cmarshhighsaltmarsh', 'brackishimpoundment', 'bnzrichfen', 'richmondbrackishmarsh', 'siwetland']

# %%
# 直接使用用户提供的时间表（字典）
# ---- 用下面这段替换旧的 schedule_dict + pairs 创建代码块 ----

# 要下载的站点列表（需要时可修改）
target_sites = [
    'northinletsaltmarsh',
    'norriepoint',
    'mayberry',
    'hillslough',
    'gcesapelo',
    'cmarshhighsaltmarsh',
    'brackishimpoundment',
    'bnzrichfen',
    'richmondbrackishmarsh',
    'siwetland',
    'vancouversaltmarsh'
]

import datetime
current_year = datetime.datetime.now().year

pairs = []   # 用来保存 (site, year) 的列表

for site in target_sites:
    if site not in roi_dict:
        print(f"  警告：在 shapefile 中未找到站点：{site}")
        continue

    ee_roi = shapely_to_ee(roi_dict[site])
    col = ee.ImageCollection(HLS_COLLECTION).filterBounds(ee_roi)

    # 检查该站点是否有任何影像
    col_size = col.size().getInfo()
    print(f"[{site}] 全部年份影像数量:", col_size)
    if col_size == 0:
        print(f"  {site} 没有找到 Sentinel-2 影像，跳过。")
        continue

    # 取按时间排序的第一张影像，获取其时间戳并转成年份
    first_img = col.sort('system:time_start').first()
    try:
        first_ts = first_img.get('system:time_start').getInfo()
        first_year = datetime.datetime.utcfromtimestamp(first_ts / 1000).year
    except Exception as e:
        print(f"  无法确定 {site} 的首年（错误：{e}），默认用 2015 年。")
        first_year = 2015

    # 从首年到当前年（包含当前年）都创建 pairs
    for y in range(first_year, current_year + 1):
        pairs.append((site, str(y)))

print("构造好的 site-year 对数量:", len(pairs))
print(pairs[:40])  # 预览前 40 项
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# [northinletsaltmarsh] 全部年份影像数量: 2502
# /tmp/ipython-input-3265127447.py:43: DeprecationWarning: datetime.datetime.utcfromtimestamp() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.fromtimestamp(timestamp, datetime.UTC).
#   first_year = datetime.datetime.utcfromtimestamp(first_ts / 1000).year
# [norriepoint] 全部年份影像数量: 1343
# [mayberry] 全部年份影像数量: 1341
# [hillslough] 全部年份影像数量: 675
# [gcesapelo] 全部年份影像数量: 621
# [cmarshhighsaltmarsh] 全部年份影像数量: 1247
# [brackishimpoundment] 全部年份影像数量: 1253
# [bnzrichfen] 全部年份影像数量: 1163
# [richmondbrackishmarsh] 全部年份影像数量: 1255
# [siwetland] 全部年份影像数量: 1341
# [vancouversaltmarsh] 全部年份影像数量: 1254
# 构造好的 site-year 对数量: 118
# [('northinletsaltmarsh', '2015'), ('northinletsaltmarsh', '2016'), ('northinletsaltmarsh', '2017'), ('northinletsaltmarsh', '2018'), ('northinletsaltmarsh', '2019'), ('northinletsaltmarsh', '2020'), ('northinletsaltmarsh', '2021'), ('northinletsaltmarsh', '2022'), ('northinletsaltmarsh', '2023'), ('northinletsaltmarsh', '2024'), ('northinletsaltmarsh', '2025'), ('norriepoint', '2015'), ('norriepoint', '2016'), ('norriepoint', '2017'), ('norriepoint', '2018'), ('norriepoint', '2019'), ('norriepoint', '2020'), ('norriepoint', '2021'), ('norriepoint', '2022'), ('norriepoint', '2023'), ('norriepoint', '2024'), ('norriepoint', '2025'), ('mayberry', '2015'), ('mayberry', '2016'), ('mayberry', '2017'), ('mayberry', '2018'), ('mayberry', '2019'), ('mayberry', '2020'), ('mayberry', '2021'), ('mayberry', '2022'), ('mayberry', '2023'), ('mayberry', '2024'), ('mayberry', '2025'), ('hillslough', '2015'), ('hillslough', '2016'), ('hillslough', '2017'), ('hillslough', '2018'), ('hillslough', '2019'), ('hillslough', '2020'), ('hillslough', '2021')]

# %%
# ---------- 辅助：把 shapely geometry 转为 ee.Geometry ----------
from shapely.geometry import mapping
def shapely_to_ee(geom):
    return ee.Geometry(mapping(geom))

# ---------- 生成掩膜函数（优先用 Fmask / QA_PIXEL，否则用经验阈值） ----------
def make_mask_function(bandnames_list):
    """
    Return a mask function adapted for Sentinel-2 SR Harmonized (QA60) and generic fallbacks.
    - If QA60 present -> use bits 10 (opaque clouds) and 11 (cirrus) to mask.
    - Else if Fmask/SCL etc present, try sensible handling.
    - Otherwise fallback to simple spectral rules (MNDWI + brightness).
    """
    bandset = set(bandnames_list)
    use_qa60 = 'QA60' in bandset or 'qa60' in bandset or 'Qa60' in bandset
    use_fmask = 'Fmask' in bandset or 'fmask' in bandset
    use_scl = 'SCL' in bandset  # scene classification layer may exist

    def mask_fn(img):
        img = ee.Image(img)

        # 1) If QA60 present -> use bits 10 and 11
        if use_qa60:
            # QA60: bit 10 = opaque clouds, bit 11 = cirrus
            qa_key = 'QA60' if 'QA60' in bandset else ('qa60' if 'qa60' in bandset else 'Qa60')
            qa = img.select(qa_key)
            opaque_cloud_bit = 1 << 10
            cirrus_bit = 1 << 11
            no_opaque = qa.bitwiseAnd(opaque_cloud_bit).eq(0)
            no_cirrus = qa.bitwiseAnd(cirrus_bit).eq(0)
            qa_mask = no_opaque.And(no_cirrus)
            return img.updateMask(qa_mask)

        # 2) If Fmask present -> follow earlier Fmask logic (if user has fmask)
        if use_fmask:
            key = 'Fmask' if 'Fmask' in bandset else 'fmask'
            fmask = img.select(key)
            # adjust bit positions according to your Fmask definition (example earlier used bits 1,3,4,5)
            cloud_bit = 1 << 1
            cloud_shadow_bit = 1 << 3
            snow_bit = 1 << 4
            water_bit = 1 << 5
            is_cloud = fmask.bitwiseAnd(cloud_bit).neq(0)
            is_cloud_shadow = fmask.bitwiseAnd(cloud_shadow_bit).neq(0)
            is_snow = fmask.bitwiseAnd(snow_bit).neq(0)
            is_water = fmask.bitwiseAnd(water_bit).neq(0)
            clear_mask = is_cloud.Not().And(is_cloud_shadow.Not()).And(is_snow.Not()).And(is_water.Not())
            return img.updateMask(clear_mask)

        # 3) If SCL (scene classification) exists -> mask cloud classes (optional)
        if use_scl:
            scl = img.select('SCL')
            # Typical SCL classes to mask: 3 = cloud shadow, 8 = medium probability cloud,
            # 9 = high probability cloud, 10 = thin cirrus, 11 = snow. This may vary by dataset.
            cloud_mask = scl.neq(3).And(scl.neq(8)).And(scl.neq(9)).And(scl.neq(10)).And(scl.neq(11))
            return img.updateMask(cloud_mask)

        # 4) Fallback: spectral rules using MNDWI and brightness (conservative)
        try:
    # select, cast to float and convert to reflectance (scale factor 0.0001)
          MNDWI = img.select(['B3','B11']).toFloat().multiply(0.0001).normalizedDifference(['B3','B11']).rename('MNDWI')
        except Exception:
          MNDWI = ee.Image(0)

        # brightness using whichever of preferred bands exist
        bnames = [b for b in PREFERRED_BANDS if b in bandnames_list]
        if len(bnames) >= 3:
    # cast + scale then compute mean brightness (reflectance domain)
          brightness = img.select(bnames[:3]).toFloat().multiply(0.0001).reduce(ee.Reducer.mean()).rename('BRIGHT')
        else:
          brightness = ee.Image(0)

        bright_ok = brightness.lt(0.9)   # filter out extremely bright pixels (likely cloud)
        not_water = MNDWI.lt(-0.1)       # keep non-water (conservative)
        final_mask = bright_ok.And(not_water)
        return img.updateMask(final_mask)

    return mask_fn

# ---------- 处理单 site-year 的函数 ----------
def process_site_year(site_name, year, roi_geom, out_drive_folder=OUT_DRIVE_FOLDER, scale=EXPORT_SCALE):
    """
    Process a single site-year:
    - filter Sentinel-2 by date & roi
    - apply mask_fn
    - compute GCC = G / (R+G+B) per observation, rename to GCC_YYYYMMdd
    - stack all GCC bands and export to Drive (one single-band-per-date stacked image)
    """
    ee_roi = shapely_to_ee(roi_geom)
    start = f'{int(year)}-01-01'
    end = f'{int(year)}-12-31'
    col = ee.ImageCollection(HLS_COLLECTION).filterDate(start, end).filterBounds(ee_roi)
    col_size = col.size().getInfo()
    print(f"[{site_name} {year}] images found:", col_size)
    if col_size == 0:
        return {'status':'no_images','site':site_name,'year':year}

    # get band names to decide availability
    first = ee.Image(col.first())
    bandnames = first.bandNames().getInfo()
    print("Example bandnames:", bandnames[:30])

    # Require B2,B3,B4 to compute GCC
    required = ['B2', 'B3', 'B4']
    if not all(b in bandnames for b in required):
        print(f"  WARNING: required bands {required} not all present for {site_name} {year}. Skipping.")
        return {'status':'missing_rgb_bands','site':site_name,'year':year}

    # Prepare mask function with available bandnames
    mask_fn = make_mask_function(bandnames)

    # Preprocess each image: mask -> clip -> compute GCC -> rename band with date
    def prep(img):
        img = ee.Image(img)
        img_masked = mask_fn(img)
        img_clip = img_masked.clip(ee_roi)
        # date string YYYYMMdd
        date = ee.Date(img_clip.get('system:time_start')).format('YYYYMMdd')

        # inside GCC prep() (per-image GCC)
        red = img_clip.select('B4').toFloat().multiply(0.0001)
        green = img_clip.select('B3').toFloat().multiply(0.0001)
        blue = img_clip.select('B2').toFloat().multiply(0.0001)

        eps = ee.Image.constant(1e-6)
        denom = red.add(green).add(blue).add(eps)
        gcc = green.divide(denom).rename(ee.String('GCC_').cat(date))


        # set index and return single-band image
        return gcc.set({'system:index': ee.String(site_name).cat('_').cat(date)})

    prepared = col.map(prep)
    prepared_count = prepared.size().getInfo()
    print(f"[{site_name} {year}] prepared (GCC computed & clipped) images:", prepared_count)
    if prepared_count == 0:
        return {'status':'no_clear_images','site':site_name,'year':year}

    # Combine into single image: every observation's GCC becomes a separate band
    stacked = prepared.toBands()

    # Start export to Drive (single image with many GCC_* bands)
    export_name = f"{site_name}_{year}_GCC"
    task = ee.batch.Export.image.toDrive(
        image=stacked,
        description=export_name,
        folder=out_drive_folder,
        fileNamePrefix=export_name,
        region=ee_roi,
        scale=scale,
        maxPixels=1e13
    )
    task.start()
    print("GCC Export started:", export_name, " -> Drive folder:", out_drive_folder)
    return {'status':'export_started','site':site_name,'year':year,'task_id': getattr(task, 'id', None)}


# ---------- 按月合成的备选方案（当波段太多时） ----------
def process_site_year_monthly(site_name, year, roi_geom, use_bands, mask_fn, out_drive_folder=OUT_DRIVE_FOLDER, scale=EXPORT_SCALE):
    ee_roi = shapely_to_ee(roi_geom)
    # 获取该年影像集合
    start = f'{int(year)}-01-01'
    end = f'{int(year)}-12-31'
    col = ee.ImageCollection(HLS_COLLECTION).filterDate(start, end).filterBounds(ee_roi)

    # 为每个月生成中位数合成
    months = list(range(1,13))
    monthly_images = []
    for m in months:
        s = ee.Date.fromYMD(int(year), m, 1)
        e = s.advance(1, 'month')
        sub = col.filterDate(s, e)
        # 预处理（掩膜 -> 选波段 -> 裁剪）
        def prep_month(img):
            img = ee.Image(img)
            img_masked = mask_fn(img).clip(ee_roi)
            red = img_masked.select('B4').toFloat().multiply(0.0001)
            green = img_masked.select('B3').toFloat().multiply(0.0001)
            blue = img_masked.select('B2').toFloat().multiply(0.0001)
            eps = ee.Image.constant(1e-6)
            denom = red.add(green).add(blue).add(eps)
            return green.divide(denom)

        sub_prep = sub.map(prep_month)
        # 如果当月没有影像，跳过
        if sub_prep.size().getInfo() == 0:
            continue
        # 用中位数合成（也可改成 median/mean）
        composite = sub_prep.median()
        # 重命名波段为 B4_YYYYMM
        date_label = ee.String(str(year)).cat(ee.String('_')).cat(ee.String(str(m).zfill(2)))
        newnames = [ee.String(b).cat('_').cat(date_label) for b in use_bands]
        composite = composite.rename(newnames)
        monthly_images.append(composite)

    if len(monthly_images) == 0:
        return {'status':'no_clear_images_monthly','site':site_name,'year':year}

    # 把月合成列表合并为单影像
    stacked_monthly = ee.ImageCollection(monthly_images).toBands()

    export_name = f"{site_name}_{year}_monthly"
    task = ee.batch.Export.image.toDrive(
        image=stacked_monthly,
        description=export_name,
        folder=out_drive_folder,
        fileNamePrefix=export_name,
        region=ee_roi,
        scale=scale,
        maxPixels=1e13
    )
    task.start()
    print("Monthly-export started:", export_name)
    return {'status':'export_started_monthly','site':site_name,'year':year,'task_id': getattr(task, 'id', None)}
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# 批量运行（使用前面构建的 pairs 列表）
results = []
started = 0
for idx, (site, year) in enumerate(pairs, start=1):
    print(f"\n[{idx}/{len(pairs)}] 开始处理： {site} - {year}")
    if site not in roi_dict:
        print("  WARNING: site 在 shapefile 中未找到：", site)
        results.append({'site':site,'year':year,'status':'site_not_found'})
        continue
    try:
        res = process_site_year(site, year, roi_dict[site], out_drive_folder=OUT_DRIVE_FOLDER, scale=EXPORT_SCALE)
        results.append(res)
        print("  结果：", res)
        started += 1
    except Exception as e:
        print("  ERROR:", str(e))
        results.append({'site':site,'year':year,'status':'error','error_msg': str(e)})
    time.sleep(SLEEP_BETWEEN_START)

# 保存日志到 Drive
with open(LOG_PATH, 'w', encoding='utf-8') as f:
    json.dump(results, f, ensure_ascii=False, indent=2)
print("\n全部任务已提交（或尝试提交）。日志已保存到：", LOG_PATH)
print("本次启动的任务数量（近似）：", started)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# [1/118] 开始处理： northinletsaltmarsh - 2015
# [northinletsaltmarsh 2015] images found: 12
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [northinletsaltmarsh 2015] prepared (GCC computed & clipped) images: 12
# GCC Export started: northinletsaltmarsh_2015_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'northinletsaltmarsh', 'year': '2015', 'task_id': 'L7BCSIB46X3GSDT3HSYMZDLT'}
#
# [2/118] 开始处理： northinletsaltmarsh - 2016
# [northinletsaltmarsh 2016] images found: 72
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [northinletsaltmarsh 2016] prepared (GCC computed & clipped) images: 72
# GCC Export started: northinletsaltmarsh_2016_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'northinletsaltmarsh', 'year': '2016', 'task_id': 'DLLDGMT76FPP5T7UKIFTFCAL'}
#
# [3/118] 开始处理： northinletsaltmarsh - 2017
# [northinletsaltmarsh 2017] images found: 126
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [northinletsaltmarsh 2017] prepared (GCC computed & clipped) images: 126
# GCC Export started: northinletsaltmarsh_2017_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'northinletsaltmarsh', 'year': '2017', 'task_id': 'WON4JGUOTFXOZY675PP223QK'}
#
# [4/118] 开始处理： northinletsaltmarsh - 2018
# [northinletsaltmarsh 2018] images found: 285
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [northinletsaltmarsh 2018] prepared (GCC computed & clipped) images: 285
# GCC Export started: northinletsaltmarsh_2018_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'northinletsaltmarsh', 'year': '2018', 'task_id': 'A76GGSHNEI4C2TYYN67B77UU'}
#
# [5/118] 开始处理： northinletsaltmarsh - 2019
# [northinletsaltmarsh 2019] images found: 290
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [northinletsaltmarsh 2019] prepared (GCC computed & clipped) images: 290
# GCC Export started: northinletsaltmarsh_2019_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'northinletsaltmarsh', 'year': '2019', 'task_id': 'RU5JLYHN3K6XD3V3FMBZUL2R'}
#
# [6/118] 开始处理： northinletsaltmarsh - 2020
# [northinletsaltmarsh 2020] images found: 286
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [northinletsaltmarsh 2020] prepared (GCC computed & clipped) images: 286
# GCC Export started: northinletsaltmarsh_2020_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'northinletsaltmarsh', 'year': '2020', 'task_id': 'IDHHN6FTDCPCDSV42CY52C4I'}
#
# [7/118] 开始处理： northinletsaltmarsh - 2021
# [northinletsaltmarsh 2021] images found: 290
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [northinletsaltmarsh 2021] prepared (GCC computed & clipped) images: 290
# GCC Export started: northinletsaltmarsh_2021_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'northinletsaltmarsh', 'year': '2021', 'task_id': 'TBZOLIBHOVWH3FBWNCE6PXBU'}
#
# [8/118] 开始处理： northinletsaltmarsh - 2022
# [northinletsaltmarsh 2022] images found: 290
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [northinletsaltmarsh 2022] prepared (GCC computed & clipped) images: 290
# GCC Export started: northinletsaltmarsh_2022_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'northinletsaltmarsh', 'year': '2022', 'task_id': 'Y7DZSOSPER6A3ZXEXCOBXUSF'}
#
# [9/118] 开始处理： northinletsaltmarsh - 2023
# [northinletsaltmarsh 2023] images found: 288
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [northinletsaltmarsh 2023] prepared (GCC computed & clipped) images: 288
# GCC Export started: northinletsaltmarsh_2023_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'northinletsaltmarsh', 'year': '2023', 'task_id': 'AVHUGF26LQJ2HLBZFMQEN5P4'}
#
# [10/118] 开始处理： northinletsaltmarsh - 2024
# [northinletsaltmarsh 2024] images found: 296
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [northinletsaltmarsh 2024] prepared (GCC computed & clipped) images: 296
# GCC Export started: northinletsaltmarsh_2024_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'northinletsaltmarsh', 'year': '2024', 'task_id': '4IEXD737PXHSVX5N3XCF3FOD'}
#
# [11/118] 开始处理： northinletsaltmarsh - 2025
# [northinletsaltmarsh 2025] images found: 259
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [northinletsaltmarsh 2025] prepared (GCC computed & clipped) images: 259
# GCC Export started: northinletsaltmarsh_2025_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'northinletsaltmarsh', 'year': '2025', 'task_id': '664PJRMG3EEHFRCHLXNW3SG5'}
#
# [12/118] 开始处理： norriepoint - 2015
# [norriepoint 2015] images found: 12
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [norriepoint 2015] prepared (GCC computed & clipped) images: 12
# GCC Export started: norriepoint_2015_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'norriepoint', 'year': '2015', 'task_id': 'IAEE6NTPRZAFWNIJTJ3L52XY'}
#
# [13/118] 开始处理： norriepoint - 2016
# [norriepoint 2016] images found: 66
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [norriepoint 2016] prepared (GCC computed & clipped) images: 66
# GCC Export started: norriepoint_2016_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'norriepoint', 'year': '2016', 'task_id': 'OIVEKNHYUNYDRG2TFMSALSEG'}
#
# [14/118] 开始处理： norriepoint - 2017
# [norriepoint 2017] images found: 123
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [norriepoint 2017] prepared (GCC computed & clipped) images: 123
# GCC Export started: norriepoint_2017_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'norriepoint', 'year': '2017', 'task_id': 'BNP3ZZ2QNAYTMILTNHYT4R4T'}
#
# [15/118] 开始处理： norriepoint - 2018
# [norriepoint 2018] images found: 142
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [norriepoint 2018] prepared (GCC computed & clipped) images: 142
# GCC Export started: norriepoint_2018_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'norriepoint', 'year': '2018', 'task_id': 'WVOMGDEK76LOZ4ZHJM66X7BF'}
#
# [16/118] 开始处理： norriepoint - 2019
# [norriepoint 2019] images found: 144
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [norriepoint 2019] prepared (GCC computed & clipped) images: 144
# GCC Export started: norriepoint_2019_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'norriepoint', 'year': '2019', 'task_id': 'RL5KUOSXZM6AERKDSYE2EWL7'}
#
# [17/118] 开始处理： norriepoint - 2020
# [norriepoint 2020] images found: 145
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [norriepoint 2020] prepared (GCC computed & clipped) images: 145
# GCC Export started: norriepoint_2020_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'norriepoint', 'year': '2020', 'task_id': 'ZA4KQOMMPQRJGBPHJUUNQURE'}
#
# [18/118] 开始处理： norriepoint - 2021
# [norriepoint 2021] images found: 144
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [norriepoint 2021] prepared (GCC computed & clipped) images: 144
# GCC Export started: norriepoint_2021_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'norriepoint', 'year': '2021', 'task_id': 'FCEYL7ZLVGIUVPXTDKHSQF77'}
#
# [19/118] 开始处理： norriepoint - 2022
# [norriepoint 2022] images found: 141
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [norriepoint 2022] prepared (GCC computed & clipped) images: 141
# GCC Export started: norriepoint_2022_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'norriepoint', 'year': '2022', 'task_id': '2UD4CBNTVV7CIHVZYZAHQFCZ'}
#
# [20/118] 开始处理： norriepoint - 2023
# [norriepoint 2023] images found: 145
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [norriepoint 2023] prepared (GCC computed & clipped) images: 145
# GCC Export started: norriepoint_2023_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'norriepoint', 'year': '2023', 'task_id': 'MUS3XTWAWQGTORGFZOQU7NV5'}
#
# [21/118] 开始处理： norriepoint - 2024
# [norriepoint 2024] images found: 148
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [norriepoint 2024] prepared (GCC computed & clipped) images: 148
# GCC Export started: norriepoint_2024_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'norriepoint', 'year': '2024', 'task_id': 'C7Y6QEV2LHVVLDMWVYH7O5CI'}
#
# [22/118] 开始处理： norriepoint - 2025
# [norriepoint 2025] images found: 129
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [norriepoint 2025] prepared (GCC computed & clipped) images: 129
# GCC Export started: norriepoint_2025_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'norriepoint', 'year': '2025', 'task_id': 'BREVDRATLMZIYHKTWOSZJY72'}
#
# [23/118] 开始处理： mayberry - 2015
# [mayberry 2015] images found: 12
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [mayberry 2015] prepared (GCC computed & clipped) images: 12
# GCC Export started: mayberry_2015_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'mayberry', 'year': '2015', 'task_id': 'ZFCGPG4L24AREHUP37H5JB5F'}
#
# [24/118] 开始处理： mayberry - 2016
# [mayberry 2016] images found: 62
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [mayberry 2016] prepared (GCC computed & clipped) images: 62
# GCC Export started: mayberry_2016_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'mayberry', 'year': '2016', 'task_id': 'GF5GP2VIQHQ6CX2S64FWLXQH'}
#
# [25/118] 开始处理： mayberry - 2017
# [mayberry 2017] images found: 108
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [mayberry 2017] prepared (GCC computed & clipped) images: 108
# GCC Export started: mayberry_2017_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'mayberry', 'year': '2017', 'task_id': 'VA6JXHNS2GX7QHYTUSANOXNK'}
#
# [26/118] 开始处理： mayberry - 2018
# [mayberry 2018] images found: 139
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [mayberry 2018] prepared (GCC computed & clipped) images: 139
# GCC Export started: mayberry_2018_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'mayberry', 'year': '2018', 'task_id': 'STPA7KGHKYCY6N4KDKFOQTCL'}
#
# [27/118] 开始处理： mayberry - 2019
# [mayberry 2019] images found: 144
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [mayberry 2019] prepared (GCC computed & clipped) images: 144
# GCC Export started: mayberry_2019_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'mayberry', 'year': '2019', 'task_id': 'ZVGDKREBXQ5W7W7DX4ZDRQSO'}
#
# [28/118] 开始处理： mayberry - 2020
# [mayberry 2020] images found: 148
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [mayberry 2020] prepared (GCC computed & clipped) images: 148
# GCC Export started: mayberry_2020_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'mayberry', 'year': '2020', 'task_id': 'OYVYX2P7RUCJ6UYXIDDY6OVG'}
#
# [29/118] 开始处理： mayberry - 2021
# [mayberry 2021] images found: 144
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [mayberry 2021] prepared (GCC computed & clipped) images: 144
# GCC Export started: mayberry_2021_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'mayberry', 'year': '2021', 'task_id': '35VP2ZVA7RZSRARUE35Z6QDT'}
#
# [30/118] 开始处理： mayberry - 2022
# [mayberry 2022] images found: 146
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [mayberry 2022] prepared (GCC computed & clipped) images: 146
# GCC Export started: mayberry_2022_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'mayberry', 'year': '2022', 'task_id': 'CZS7SCO75UUQEO2X5KL3YXCD'}
#
# [31/118] 开始处理： mayberry - 2023
# [mayberry 2023] images found: 146
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [mayberry 2023] prepared (GCC computed & clipped) images: 146
# GCC Export started: mayberry_2023_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'mayberry', 'year': '2023', 'task_id': '2ODHDKQYMCVQVWLMZWUI4VW3'}
#
# [32/118] 开始处理： mayberry - 2024
# [mayberry 2024] images found: 146
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [mayberry 2024] prepared (GCC computed & clipped) images: 146
# GCC Export started: mayberry_2024_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'mayberry', 'year': '2024', 'task_id': 'LA2XAPHQ5HANKEDIXNWCQZSA'}
#
# [33/118] 开始处理： mayberry - 2025
# [mayberry 2025] images found: 138
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [mayberry 2025] prepared (GCC computed & clipped) images: 138
# GCC Export started: mayberry_2025_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'mayberry', 'year': '2025', 'task_id': 'OGWCEIM7LX5IK7US26DOWN2B'}
#
# [34/118] 开始处理： hillslough - 2015
# [hillslough 2015] images found: 6
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [hillslough 2015] prepared (GCC computed & clipped) images: 6
# GCC Export started: hillslough_2015_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'hillslough', 'year': '2015', 'task_id': 'XJJNDEIUHKEBLJWOBWM4EIDX'}
#
# [35/118] 开始处理： hillslough - 2016
# [hillslough 2016] images found: 31
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [hillslough 2016] prepared (GCC computed & clipped) images: 31
# GCC Export started: hillslough_2016_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'hillslough', 'year': '2016', 'task_id': '2TH6ZVYM5DPBSJGBBVX6JCHX'}
#
# [36/118] 开始处理： hillslough - 2017
# [hillslough 2017] images found: 53
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [hillslough 2017] prepared (GCC computed & clipped) images: 53
# GCC Export started: hillslough_2017_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'hillslough', 'year': '2017', 'task_id': '2E6SNKHWWVS5P2KEABUJPD3I'}
#
# [37/118] 开始处理： hillslough - 2018
# [hillslough 2018] images found: 71
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [hillslough 2018] prepared (GCC computed & clipped) images: 71
# GCC Export started: hillslough_2018_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'hillslough', 'year': '2018', 'task_id': 'RSZXWILAWKGCMVBCU24ZHHXY'}
#
# [38/118] 开始处理： hillslough - 2019
# [hillslough 2019] images found: 73
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [hillslough 2019] prepared (GCC computed & clipped) images: 73
# GCC Export started: hillslough_2019_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'hillslough', 'year': '2019', 'task_id': 'DJJTW3IG32DEDOFR3BYQLQ3U'}
#
# [39/118] 开始处理： hillslough - 2020
# [hillslough 2020] images found: 74
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [hillslough 2020] prepared (GCC computed & clipped) images: 74
# GCC Export started: hillslough_2020_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'hillslough', 'year': '2020', 'task_id': 'C2PW5K63FM3G2XM5KZKQOKVS'}
#
# [40/118] 开始处理： hillslough - 2021
# [hillslough 2021] images found: 73
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [hillslough 2021] prepared (GCC computed & clipped) images: 73
# GCC Export started: hillslough_2021_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'hillslough', 'year': '2021', 'task_id': 'EJE2VWVMC3EQ7QMOYBKCCIG7'}
#
# [41/118] 开始处理： hillslough - 2022
# [hillslough 2022] images found: 73
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [hillslough 2022] prepared (GCC computed & clipped) images: 73
# GCC Export started: hillslough_2022_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'hillslough', 'year': '2022', 'task_id': 'XGXMP6BCOXXYSGWABSIA3K6O'}
#
# [42/118] 开始处理： hillslough - 2023
# [hillslough 2023] images found: 73
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [hillslough 2023] prepared (GCC computed & clipped) images: 73
# GCC Export started: hillslough_2023_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'hillslough', 'year': '2023', 'task_id': '2NSRTA6LEFFHNWSLN5XBRS76'}
#
# [43/118] 开始处理： hillslough - 2024
# [hillslough 2024] images found: 74
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [hillslough 2024] prepared (GCC computed & clipped) images: 74
# GCC Export started: hillslough_2024_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'hillslough', 'year': '2024', 'task_id': '2WKWFC5CNKGRG3RNWISZOUT3'}
#
# [44/118] 开始处理： hillslough - 2025
# [hillslough 2025] images found: 70
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [hillslough 2025] prepared (GCC computed & clipped) images: 70
# GCC Export started: hillslough_2025_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'hillslough', 'year': '2025', 'task_id': 'IZUMS4URVXWFUCREOYZL6P2T'}
#
# [45/118] 开始处理： gcesapelo - 2015
# [gcesapelo 2015] images found: 3
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [gcesapelo 2015] prepared (GCC computed & clipped) images: 3
# GCC Export started: gcesapelo_2015_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'gcesapelo', 'year': '2015', 'task_id': 'KGM2EEOCHBMGGOYRJ7VHWARO'}
#
# [46/118] 开始处理： gcesapelo - 2016
# [gcesapelo 2016] images found: 17
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [gcesapelo 2016] prepared (GCC computed & clipped) images: 17
# GCC Export started: gcesapelo_2016_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'gcesapelo', 'year': '2016', 'task_id': '2WNLW7EJD3FGS2FCPXBVH4H7'}
#
# [47/118] 开始处理： gcesapelo - 2017
# [gcesapelo 2017] images found: 30
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [gcesapelo 2017] prepared (GCC computed & clipped) images: 30
# GCC Export started: gcesapelo_2017_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'gcesapelo', 'year': '2017', 'task_id': 'DQ4COMSYMRX333J5GVW5ZKHU'}
#
# [48/118] 开始处理： gcesapelo - 2018
# [gcesapelo 2018] images found: 71
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [gcesapelo 2018] prepared (GCC computed & clipped) images: 71
# GCC Export started: gcesapelo_2018_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'gcesapelo', 'year': '2018', 'task_id': 'Q57NKTXVU3PNWB56YWHLYQ6E'}
#
# [49/118] 开始处理： gcesapelo - 2019
# [gcesapelo 2019] images found: 74
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [gcesapelo 2019] prepared (GCC computed & clipped) images: 74
# GCC Export started: gcesapelo_2019_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'gcesapelo', 'year': '2019', 'task_id': 'YXMSZR6OQGOWAAH6BUTFAESL'}
#
# [50/118] 开始处理： gcesapelo - 2020
# [gcesapelo 2020] images found: 69
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [gcesapelo 2020] prepared (GCC computed & clipped) images: 69
# GCC Export started: gcesapelo_2020_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'gcesapelo', 'year': '2020', 'task_id': '2T7QFJK3QUXCBNFEJQQCEWZY'}
#
# [51/118] 开始处理： gcesapelo - 2021
# [gcesapelo 2021] images found: 72
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [gcesapelo 2021] prepared (GCC computed & clipped) images: 72
# GCC Export started: gcesapelo_2021_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'gcesapelo', 'year': '2021', 'task_id': '7INI4VLJCTRV32E74YM7DYBH'}
#
# [52/118] 开始处理： gcesapelo - 2022
# [gcesapelo 2022] images found: 74
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [gcesapelo 2022] prepared (GCC computed & clipped) images: 74
# GCC Export started: gcesapelo_2022_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'gcesapelo', 'year': '2022', 'task_id': '3D4FI2UIMNUWJ7RAC76WKT3F'}
#
# [53/118] 开始处理： gcesapelo - 2023
# [gcesapelo 2023] images found: 72
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [gcesapelo 2023] prepared (GCC computed & clipped) images: 72
# GCC Export started: gcesapelo_2023_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'gcesapelo', 'year': '2023', 'task_id': 'PPTPZC7ZDYIZQPGE7JZ2NXR5'}
#
# [54/118] 开始处理： gcesapelo - 2024
# [gcesapelo 2024] images found: 74
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [gcesapelo 2024] prepared (GCC computed & clipped) images: 74
# GCC Export started: gcesapelo_2024_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'gcesapelo', 'year': '2024', 'task_id': 'BXRCRUQ3Z4JENFHPIQFBUMQS'}
#
# [55/118] 开始处理： gcesapelo - 2025
# [gcesapelo 2025] images found: 65
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [gcesapelo 2025] prepared (GCC computed & clipped) images: 65
# GCC Export started: gcesapelo_2025_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'gcesapelo', 'year': '2025', 'task_id': 'CTTYU62J2XKB45D6B4XL3KLF'}
#
# [56/118] 开始处理： cmarshhighsaltmarsh - 2015
# [cmarshhighsaltmarsh 2015] images found: 7
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [cmarshhighsaltmarsh 2015] prepared (GCC computed & clipped) images: 7
# GCC Export started: cmarshhighsaltmarsh_2015_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'cmarshhighsaltmarsh', 'year': '2015', 'task_id': 'T66FQOWTMBYJ3A4C4MCVXD2C'}
#
# [57/118] 开始处理： cmarshhighsaltmarsh - 2016
# [cmarshhighsaltmarsh 2016] images found: 34
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [cmarshhighsaltmarsh 2016] prepared (GCC computed & clipped) images: 34
# GCC Export started: cmarshhighsaltmarsh_2016_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'cmarshhighsaltmarsh', 'year': '2016', 'task_id': 'RMM6WAJAW7L2UKKCUJ2HLMOJ'}
#
# [58/118] 开始处理： cmarshhighsaltmarsh - 2017
# [cmarshhighsaltmarsh 2017] images found: 61
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [cmarshhighsaltmarsh 2017] prepared (GCC computed & clipped) images: 61
# GCC Export started: cmarshhighsaltmarsh_2017_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'cmarshhighsaltmarsh', 'year': '2017', 'task_id': 'ESAXR63W24Q7RA6EGX5NVKOP'}
#
# [59/118] 开始处理： cmarshhighsaltmarsh - 2018
# [cmarshhighsaltmarsh 2018] images found: 141
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [cmarshhighsaltmarsh 2018] prepared (GCC computed & clipped) images: 141
# GCC Export started: cmarshhighsaltmarsh_2018_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'cmarshhighsaltmarsh', 'year': '2018', 'task_id': 'O6KR7CLFF4B2Q6CVH63NLCBH'}
#
# [60/118] 开始处理： cmarshhighsaltmarsh - 2019
# [cmarshhighsaltmarsh 2019] images found: 145
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [cmarshhighsaltmarsh 2019] prepared (GCC computed & clipped) images: 145
# GCC Export started: cmarshhighsaltmarsh_2019_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'cmarshhighsaltmarsh', 'year': '2019', 'task_id': 'XPR5DQFOLUY4VRKL2XC36RMR'}
#
# [61/118] 开始处理： cmarshhighsaltmarsh - 2020
# [cmarshhighsaltmarsh 2020] images found: 146
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [cmarshhighsaltmarsh 2020] prepared (GCC computed & clipped) images: 146
# GCC Export started: cmarshhighsaltmarsh_2020_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'cmarshhighsaltmarsh', 'year': '2020', 'task_id': '4GWALLT7EJ2EMBIYA43OWJ5P'}
#
# [62/118] 开始处理： cmarshhighsaltmarsh - 2021
# [cmarshhighsaltmarsh 2021] images found: 146
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [cmarshhighsaltmarsh 2021] prepared (GCC computed & clipped) images: 146
# GCC Export started: cmarshhighsaltmarsh_2021_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'cmarshhighsaltmarsh', 'year': '2021', 'task_id': 'RJDSDMHEKM235GZ5HYBF65EW'}
#
# [63/118] 开始处理： cmarshhighsaltmarsh - 2022
# [cmarshhighsaltmarsh 2022] images found: 143
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [cmarshhighsaltmarsh 2022] prepared (GCC computed & clipped) images: 143
# GCC Export started: cmarshhighsaltmarsh_2022_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'cmarshhighsaltmarsh', 'year': '2022', 'task_id': '6ETOTMKUJ6VTQVDFURO72RPP'}
#
# [64/118] 开始处理： cmarshhighsaltmarsh - 2023
# [cmarshhighsaltmarsh 2023] images found: 142
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [cmarshhighsaltmarsh 2023] prepared (GCC computed & clipped) images: 142
# GCC Export started: cmarshhighsaltmarsh_2023_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'cmarshhighsaltmarsh', 'year': '2023', 'task_id': '7CVJMBZWGOBBXERUCETYXQ3R'}
#
# [65/118] 开始处理： cmarshhighsaltmarsh - 2024
# [cmarshhighsaltmarsh 2024] images found: 148
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [cmarshhighsaltmarsh 2024] prepared (GCC computed & clipped) images: 148
# GCC Export started: cmarshhighsaltmarsh_2024_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'cmarshhighsaltmarsh', 'year': '2024', 'task_id': '3FURGGIJMWBU4GC4W7P5DXDW'}
#
# [66/118] 开始处理： cmarshhighsaltmarsh - 2025
# [cmarshhighsaltmarsh 2025] images found: 129
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [cmarshhighsaltmarsh 2025] prepared (GCC computed & clipped) images: 129
# GCC Export started: cmarshhighsaltmarsh_2025_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'cmarshhighsaltmarsh', 'year': '2025', 'task_id': 'NFZAAAIZYHIVTYMJN26L2OIK'}
#
# [67/118] 开始处理： brackishimpoundment - 2015
# [brackishimpoundment 2015] images found: 6
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [brackishimpoundment 2015] prepared (GCC computed & clipped) images: 6
# GCC Export started: brackishimpoundment_2015_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'brackishimpoundment', 'year': '2015', 'task_id': 'KWZAJP5G2FWPMVJIURQI22JG'}
#
# [68/118] 开始处理： brackishimpoundment - 2016
# [brackishimpoundment 2016] images found: 35
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [brackishimpoundment 2016] prepared (GCC computed & clipped) images: 35
# GCC Export started: brackishimpoundment_2016_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'brackishimpoundment', 'year': '2016', 'task_id': 'XVVFDO4DJO4K2MY2OZN3G4FQ'}
#
# [69/118] 开始处理： brackishimpoundment - 2017
# [brackishimpoundment 2017] images found: 63
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [brackishimpoundment 2017] prepared (GCC computed & clipped) images: 63
# GCC Export started: brackishimpoundment_2017_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'brackishimpoundment', 'year': '2017', 'task_id': 'OV35NEZL6WMDZZNJFJIBTMN6'}
#
# [70/118] 开始处理： brackishimpoundment - 2018
# [brackishimpoundment 2018] images found: 141
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [brackishimpoundment 2018] prepared (GCC computed & clipped) images: 141
# GCC Export started: brackishimpoundment_2018_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'brackishimpoundment', 'year': '2018', 'task_id': 'MROK46TXKSARJL5OHTLD7FEN'}
#
# [71/118] 开始处理： brackishimpoundment - 2019
# [brackishimpoundment 2019] images found: 147
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [brackishimpoundment 2019] prepared (GCC computed & clipped) images: 147
# GCC Export started: brackishimpoundment_2019_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'brackishimpoundment', 'year': '2019', 'task_id': 'TBS5X3LHKDDONPUG5KQCRIS3'}
#
# [72/118] 开始处理： brackishimpoundment - 2020
# [brackishimpoundment 2020] images found: 141
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [brackishimpoundment 2020] prepared (GCC computed & clipped) images: 141
# GCC Export started: brackishimpoundment_2020_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'brackishimpoundment', 'year': '2020', 'task_id': 'TFTCNLCVXYVOFR544CQP3UFT'}
#
# [73/118] 开始处理： brackishimpoundment - 2021
# [brackishimpoundment 2021] images found: 145
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [brackishimpoundment 2021] prepared (GCC computed & clipped) images: 145
# GCC Export started: brackishimpoundment_2021_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'brackishimpoundment', 'year': '2021', 'task_id': 'E472JVLFJ4GNX5J4Y7E6XYEM'}
#
# [74/118] 开始处理： brackishimpoundment - 2022
# [brackishimpoundment 2022] images found: 148
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [brackishimpoundment 2022] prepared (GCC computed & clipped) images: 148
# GCC Export started: brackishimpoundment_2022_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'brackishimpoundment', 'year': '2022', 'task_id': 'HY2BVFAPAQMNCAFWJPP3EPZR'}
#
# [75/118] 开始处理： brackishimpoundment - 2023
# [brackishimpoundment 2023] images found: 144
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [brackishimpoundment 2023] prepared (GCC computed & clipped) images: 144
# GCC Export started: brackishimpoundment_2023_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'brackishimpoundment', 'year': '2023', 'task_id': 'BHK2U2WHKAHE6MORWBUG5KEC'}
#
# [76/118] 开始处理： brackishimpoundment - 2024
# [brackishimpoundment 2024] images found: 148
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [brackishimpoundment 2024] prepared (GCC computed & clipped) images: 148
# GCC Export started: brackishimpoundment_2024_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'brackishimpoundment', 'year': '2024', 'task_id': 'ZGL4HDRETWM7ALTBBU75GCUI'}
#
# [77/118] 开始处理： brackishimpoundment - 2025
# [brackishimpoundment 2025] images found: 131
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [brackishimpoundment 2025] prepared (GCC computed & clipped) images: 131
# GCC Export started: brackishimpoundment_2025_GCC  -> Drive folder: sential2GCC_exports_final_allData
# ...
# [richmondbrackishmarsh 2022] prepared (GCC computed & clipped) images: 147
# GCC Export started: richmondbrackishmarsh_2022_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'richmondbrackishmarsh', 'year': '2022', 'task_id': 'VFRLXXUVC6WLAOEW2TDFRVDN'}
#
# [94/118] 开始处理： richmondbrackishmarsh - 2023
# [richmondbrackishmarsh 2023] images found: 144
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [richmondbrackishmarsh 2023] prepared (GCC computed & clipped) images: 144
# GCC Export started: richmondbrackishmarsh_2023_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'richmondbrackishmarsh', 'year': '2023', 'task_id': 'A665L337AU7DOKABLACFDMZ3'}
#
# [95/118] 开始处理： richmondbrackishmarsh - 2024
# [richmondbrackishmarsh 2024] images found: 148
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [richmondbrackishmarsh 2024] prepared (GCC computed & clipped) images: 148
# GCC Export started: richmondbrackishmarsh_2024_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'richmondbrackishmarsh', 'year': '2024', 'task_id': '57JPANJGJU5JTZIB6GW3LT4V'}
#
# [96/118] 开始处理： richmondbrackishmarsh - 2025
# [richmondbrackishmarsh 2025] images found: 131
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [richmondbrackishmarsh 2025] prepared (GCC computed & clipped) images: 131
# GCC Export started: richmondbrackishmarsh_2025_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'richmondbrackishmarsh', 'year': '2025', 'task_id': 'PU73I3XBVNJQR7XLAZVU37XW'}
#
# [97/118] 开始处理： siwetland - 2015
# [siwetland 2015] images found: 12
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [siwetland 2015] prepared (GCC computed & clipped) images: 12
# GCC Export started: siwetland_2015_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'siwetland', 'year': '2015', 'task_id': 'DQNLI3DIOUD3ESC7H2PNO5ZO'}
#
# [98/118] 开始处理： siwetland - 2016
# [siwetland 2016] images found: 62
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [siwetland 2016] prepared (GCC computed & clipped) images: 62
# GCC Export started: siwetland_2016_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'siwetland', 'year': '2016', 'task_id': '62BHKAOV3FDPP4OTAU5VMWAP'}
#
# [99/118] 开始处理： siwetland - 2017
# [siwetland 2017] images found: 108
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [siwetland 2017] prepared (GCC computed & clipped) images: 108
# GCC Export started: siwetland_2017_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'siwetland', 'year': '2017', 'task_id': 'GP7UPDGYL4B4AOPAWBFGGHTS'}
#
# [100/118] 开始处理： siwetland - 2018
# [siwetland 2018] images found: 139
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [siwetland 2018] prepared (GCC computed & clipped) images: 139
# GCC Export started: siwetland_2018_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'siwetland', 'year': '2018', 'task_id': 'CJDV54IA6RT7DZH7PMXET7BD'}
#
# [101/118] 开始处理： siwetland - 2019
# [siwetland 2019] images found: 144
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [siwetland 2019] prepared (GCC computed & clipped) images: 144
# GCC Export started: siwetland_2019_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'siwetland', 'year': '2019', 'task_id': 'DL5LHHOA3L5STBHPBHDPFW7O'}
#
# [102/118] 开始处理： siwetland - 2020
# [siwetland 2020] images found: 148
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [siwetland 2020] prepared (GCC computed & clipped) images: 148
# GCC Export started: siwetland_2020_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'siwetland', 'year': '2020', 'task_id': '5QDALKGJV3RKILZBCTNGJO7L'}
#
# [103/118] 开始处理： siwetland - 2021
# [siwetland 2021] images found: 144
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [siwetland 2021] prepared (GCC computed & clipped) images: 144
# GCC Export started: siwetland_2021_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'siwetland', 'year': '2021', 'task_id': 'DQW6IDHVDWLN2WJ6COECQCZV'}
#
# [104/118] 开始处理： siwetland - 2022
# [siwetland 2022] images found: 146
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [siwetland 2022] prepared (GCC computed & clipped) images: 146
# GCC Export started: siwetland_2022_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'siwetland', 'year': '2022', 'task_id': 'QQ6QTIWIGGU6UOLOKLXQXNGP'}
#
# [105/118] 开始处理： siwetland - 2023
# [siwetland 2023] images found: 146
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [siwetland 2023] prepared (GCC computed & clipped) images: 146
# GCC Export started: siwetland_2023_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'siwetland', 'year': '2023', 'task_id': 'E5K5V5J46KGXE4ZA5EDZ5C6P'}
#
# [106/118] 开始处理： siwetland - 2024
# [siwetland 2024] images found: 146
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [siwetland 2024] prepared (GCC computed & clipped) images: 146
# GCC Export started: siwetland_2024_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'siwetland', 'year': '2024', 'task_id': 'WDB4UIGISVNAJLGMSPJWVV4A'}
#
# [107/118] 开始处理： siwetland - 2025
# [siwetland 2025] images found: 138
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [siwetland 2025] prepared (GCC computed & clipped) images: 138
# GCC Export started: siwetland_2025_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'siwetland', 'year': '2025', 'task_id': 'OCJVIGNNRNUWG2OTRYUBS5I7'}
#
# [108/118] 开始处理： vancouversaltmarsh - 2015
# [vancouversaltmarsh 2015] images found: 8
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [vancouversaltmarsh 2015] prepared (GCC computed & clipped) images: 8
# GCC Export started: vancouversaltmarsh_2015_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'vancouversaltmarsh', 'year': '2015', 'task_id': 'SZBJI4BPWR62DZ7UXY2AITD4'}
#
# [109/118] 开始处理： vancouversaltmarsh - 2016
# [vancouversaltmarsh 2016] images found: 30
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [vancouversaltmarsh 2016] prepared (GCC computed & clipped) images: 30
# GCC Export started: vancouversaltmarsh_2016_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'vancouversaltmarsh', 'year': '2016', 'task_id': 'XWA63W64HDS2C6K453ZNPOJ2'}
#
# [110/118] 开始处理： vancouversaltmarsh - 2017
# [vancouversaltmarsh 2017] images found: 66
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [vancouversaltmarsh 2017] prepared (GCC computed & clipped) images: 66
# GCC Export started: vancouversaltmarsh_2017_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'vancouversaltmarsh', 'year': '2017', 'task_id': 'KLC5TNVNYGYKSYLIPNQXMXVK'}
#
# [111/118] 开始处理： vancouversaltmarsh - 2018
# [vancouversaltmarsh 2018] images found: 138
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [vancouversaltmarsh 2018] prepared (GCC computed & clipped) images: 138
# GCC Export started: vancouversaltmarsh_2018_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'vancouversaltmarsh', 'year': '2018', 'task_id': 'J6P5SDUCKSZB2UC5M25PMH5I'}
#
# [112/118] 开始处理： vancouversaltmarsh - 2019
# [vancouversaltmarsh 2019] images found: 144
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [vancouversaltmarsh 2019] prepared (GCC computed & clipped) images: 144
# GCC Export started: vancouversaltmarsh_2019_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'vancouversaltmarsh', 'year': '2019', 'task_id': '32U5T7NHMMXRSB45SJID6ALZ'}
#
# [113/118] 开始处理： vancouversaltmarsh - 2020
# [vancouversaltmarsh 2020] images found: 146
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [vancouversaltmarsh 2020] prepared (GCC computed & clipped) images: 146
# GCC Export started: vancouversaltmarsh_2020_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'vancouversaltmarsh', 'year': '2020', 'task_id': 'SLGAWGLSJKKVCZUEI56OUR6M'}
#
# [114/118] 开始处理： vancouversaltmarsh - 2021
# [vancouversaltmarsh 2021] images found: 144
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [vancouversaltmarsh 2021] prepared (GCC computed & clipped) images: 144
# GCC Export started: vancouversaltmarsh_2021_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'vancouversaltmarsh', 'year': '2021', 'task_id': '24BQ6CZF5L3H4BCH2USGHOLW'}
#
# [115/118] 开始处理： vancouversaltmarsh - 2022
# [vancouversaltmarsh 2022] images found: 148
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [vancouversaltmarsh 2022] prepared (GCC computed & clipped) images: 148
# GCC Export started: vancouversaltmarsh_2022_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'vancouversaltmarsh', 'year': '2022', 'task_id': 'ALQXDWAYKASXNBI3MHCKRQWB'}
#
# [116/118] 开始处理： vancouversaltmarsh - 2023
# [vancouversaltmarsh 2023] images found: 142
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [vancouversaltmarsh 2023] prepared (GCC computed & clipped) images: 142
# GCC Export started: vancouversaltmarsh_2023_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'vancouversaltmarsh', 'year': '2023', 'task_id': 'CBORNU3DDBOYLTC5TFOSBSQ3'}
#
# [117/118] 开始处理： vancouversaltmarsh - 2024
# [vancouversaltmarsh 2024] images found: 148
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [vancouversaltmarsh 2024] prepared (GCC computed & clipped) images: 148
# GCC Export started: vancouversaltmarsh_2024_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'vancouversaltmarsh', 'year': '2024', 'task_id': 'PMFMS7FUCWIZZMBAUQNB67SG'}
#
# [118/118] 开始处理： vancouversaltmarsh - 2025
# [vancouversaltmarsh 2025] images found: 132
# Example bandnames: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# [vancouversaltmarsh 2025] prepared (GCC computed & clipped) images: 132
# GCC Export started: vancouversaltmarsh_2025_GCC  -> Drive folder: sential2GCC_exports_final_allData
#   结果： {'status': 'export_started', 'site': 'vancouversaltmarsh', 'year': '2025', 'task_id': 'D47BU2QC466MGEFMAYWONAFN'}
#
# 全部任务已提交（或尝试提交）。日志已保存到： /content/drive/MyDrive/allRoi/sential2_export_log.json
# 本次启动的任务数量（近似）： 118
